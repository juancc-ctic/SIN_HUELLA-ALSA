# %% [markdown]
# # Script de análisis inicial de conjunto de datos en el proyecto SIN_HUELLA [ALSA]

# %% [markdown]
# 4 fuentes de datos:
#
# 1. WO.csv: Work Orders
# 2. SR_completo.csv: Solicitudes de reparación, que al ser aceptadas se convierten en una WO
# 3. MOBRA.csv: Mano de obra, que son cada una de las tareas realizadas para completar una WO
# 4. ACTIVOS.csv: lista de vehículos con sus características

# %%
import pandas as pd

# %%
path ="./data/"

sr = pd.read_csv(path + 'SR_completo.csv', delimiter=";")
mobra = pd.read_csv(path + 'MOBRA.csv', delimiter=";")
wo = pd.read_csv(path + 'WO.csv', delimiter=";")
activos = pd.read_csv(path + 'ACTIVOS.csv', delimiter=";")
